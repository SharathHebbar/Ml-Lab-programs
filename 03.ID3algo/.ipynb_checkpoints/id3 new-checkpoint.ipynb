# %%
import pandas as pd
import math
import numpy as np

data = pd.read_csv("data.csv")
features = [feat for feat in data]


features.remove("Target")


print("fea:",features)

class Node:
    def __init__(self):
        self.children = []
        self.value = ""
        self.isLeaf = False
        self.pred = ""

def entropy(examples):
    pos = 0.0
    neg = 0.0
    for _, row in examples.iterrows():
        #print("row: ",_,row)
        print("pn before",pos,neg)
        print(row["Target"])
        s = row["Target"]
        if (s == "yes"):
            pos += 1
        else:
            neg += 1
    print("pn",pos,neg)
    if pos == 0.0 or neg == 0.0:
        return 0.0
    else:
        p = pos / (pos + neg)
        n = neg / (pos + neg)
        return -(p * math.log(p, 2) + n * math.log(n, 2))

def info_gain(examples, attr):
    print(attr)
    uniq = np.unique(examples[attr])
    print(uniq)
   
    gain = entropy(examples)
    print("gain(s): ",gain)

    for u in uniq:
        subdata = examples[examples[attr] == u]
     
        sub_e = entropy(subdata)
        gain -= (float(len(subdata)) / float(len(examples))) * sub_e
    
    return gain

def ID3(examples, attrs):
    root = Node()
    max_gain = 0
    max_feat = ""
    for feature in attrs:
        print('Features: ',feature)
        gain = info_gain(examples, feature)
        print("gain: ",gain)
        print("maxgain: ",max_gain)
        if gain > max_gain:
            max_gain = gain
            max_feat = feature
        print("max: ",max_feat)
    root.value = max_feat
    uniq = np.unique(examples[max_feat])
    for u in uniq:
        subdata = examples[examples[max_feat] == u]
        
        if entropy(subdata) == 0.0:
            newNode = Node()
            newNode.isLeaf = True
            newNode.value = u
            newNode.pred = np.unique(subdata["Target"])
            root.children.append(newNode)
        else:
            dummyNode = Node()
            dummyNode.value = u
            new_attrs = attrs.copy()
            new_attrs.remove(max_feat)
            child = ID3(subdata, new_attrs)
            dummyNode.children.append(child)
            root.children.append(dummyNode)
    return root

def printTree(root: Node, depth=0):
    for i in range(depth):
        print("\t", end="")
    print(root.value, end="")
    if root.isLeaf:
        print(" -> ", root.pred)
    print()
    for child in root.children:
        printTree(child, depth + 1)

root = ID3(data, features)
printTree(root)
# Out:
# fea: ['Outlook', 'Temperature', 'Humidity', 'Wind']
# Features:  Outlook
# Outlook
# ['overcast' 'rain' 'sunny']
# pn before 0.0 0.0
# no
# pn before 0.0 1.0
# no
# pn before 0.0 2.0
# yes
# pn before 0.0 3.0
# yes
# pn before 0.0 4.0
# yes
# pn before 0.0 5.0
# no
# pn before 0.0 6.0
# yes
# pn before 0.0 7.0
# no
# pn before 0.0 8.0
# yes
# pn before 0.0 9.0
# yes
# pn before 0.0 10.0
# yes
# pn before 0.0 11.0
# yes
# pn before 0.0 12.0
# yes
# pn before 0.0 13.0
# no
# pn 0.0 14.0
# gain(s):  0.0
# pn before 0.0 0.0
# yes
# pn before 0.0 1.0
# yes
# pn before 0.0 2.0
# yes
# pn before 0.0 3.0
# yes
# pn 0.0 4.0
# pn before 0.0 0.0
# yes
# pn before 0.0 1.0
# yes
# pn before 0.0 2.0
# no
# pn before 0.0 3.0
# yes
# pn before 0.0 4.0
# no
# pn 0.0 5.0
# pn before 0.0 0.0
# no
# pn before 0.0 1.0
# no
# pn before 0.0 2.0
# no
# pn before 0.0 3.0
# yes
# pn before 0.0 4.0
# yes
# pn 0.0 5.0
# gain:  0.0
# maxgain:  0
# max:
# Features:  Temperature
# Temperature
# ['cool' 'hot' 'mild']
# pn before 0.0 0.0
# no
# pn before 0.0 1.0
# no
# pn before 0.0 2.0
# yes
# pn before 0.0 3.0
# yes
# pn before 0.0 4.0
# yes
# pn before 0.0 5.0
# no
# pn before 0.0 6.0
# yes
# pn before 0.0 7.0
# no
# pn before 0.0 8.0
# yes
# pn before 0.0 9.0
# yes
# pn before 0.0 10.0
# yes
# pn before 0.0 11.0
# yes
# pn before 0.0 12.0
# yes
# pn before 0.0 13.0
# no
# pn 0.0 14.0
# gain(s):  0.0
# pn before 0.0 0.0
# yes
# pn before 0.0 1.0
# no
# pn before 0.0 2.0
# yes
# pn before 0.0 3.0
# yes
# pn 0.0 4.0
# pn before 0.0 0.0
# no
# pn before 0.0 1.0
# no
# pn before 0.0 2.0
# yes
# pn before 0.0 3.0
# yes
# pn 0.0 4.0
# pn before 0.0 0.0
# yes
# pn before 0.0 1.0
# no
# pn before 0.0 2.0
# yes
# pn before 0.0 3.0
# yes
# pn before 0.0 4.0
# yes
# pn before 0.0 5.0
# no
# pn 0.0 6.0
# gain:  0.0
# maxgain:  0
# max:
# Features:  Humidity
# Humidity
# ['high' 'normal']
# pn before 0.0 0.0
# no
# pn before 0.0 1.0
# no
# pn before 0.0 2.0
# yes
# pn before 0.0 3.0
# yes
# pn before 0.0 4.0
# yes
# pn before 0.0 5.0
# no
# pn before 0.0 6.0
# yes
# pn before 0.0 7.0
# no
# pn before 0.0 8.0
# yes
# pn before 0.0 9.0
# yes
# pn before 0.0 10.0
# yes
# pn before 0.0 11.0
# yes
# pn before 0.0 12.0
# yes
# pn before 0.0 13.0
# no
# pn 0.0 14.0
# gain(s):  0.0
# pn before 0.0 0.0
# no
# pn before 0.0 1.0
# no
# pn before 0.0 2.0
# yes
# pn before 0.0 3.0
# yes
# pn before 0.0 4.0
# no
# pn before 0.0 5.0
# yes
# pn before 0.0 6.0
# no
# pn 0.0 7.0
# pn before 0.0 0.0
# yes
# pn before 0.0 1.0
# no
# pn before 0.0 2.0
# yes
# pn before 0.0 3.0
# yes
# pn before 0.0 4.0
# yes
# pn before 0.0 5.0
# yes
# pn before 0.0 6.0
# yes
# pn 0.0 7.0
# gain:  0.0
# maxgain:  0
# max:
# Features:  Wind
# Wind
# ['strong' 'weak']
# pn before 0.0 0.0
# no
# pn before 0.0 1.0
# no
# pn before 0.0 2.0
# yes
# pn before 0.0 3.0
# yes
# pn before 0.0 4.0
# yes
# pn before 0.0 5.0
# no
# pn before 0.0 6.0
# yes
# pn before 0.0 7.0
# no
# pn before 0.0 8.0
# yes
# pn before 0.0 9.0
# yes
# pn before 0.0 10.0
# yes
# pn before 0.0 11.0
# yes
# pn before 0.0 12.0
# yes
# pn before 0.0 13.0
# no
# pn 0.0 14.0
# gain(s):  0.0
# pn before 0.0 0.0
# no
# pn before 0.0 1.0
# no
# pn before 0.0 2.0
# yes
# pn before 0.0 3.0
# yes
# pn before 0.0 4.0
# yes
# pn before 0.0 5.0
# no
# pn 0.0 6.0
# pn before 0.0 0.0
# no
# pn before 0.0 1.0
# yes
# pn before 0.0 2.0
# yes
# pn before 0.0 3.0
# yes
# pn before 0.0 4.0
# no
# pn before 0.0 5.0
# yes
# pn before 0.0 6.0
# yes
# pn before 0.0 7.0
# yes
# pn 0.0 8.0
# gain:  0.0
# maxgain:  0
# max:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\hebbar\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\users\hebbar\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\users\hebbar\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1080/3920409082.py in <module>
#      98         printTree(child, depth + 1)
#      99
# --> 100 root = ID3(data, features)
#     101 printTree(root)
#
# ~\AppData\Local\Temp/ipykernel_1080/3920409082.py in ID3(examples, attrs)
#      68         print("max: ",max_feat)
#      69     root.value = max_feat
# ---> 70     uniq = np.unique(examples[max_feat])
#      71     for u in uniq:
#      72         subdata = examples[examples[max_feat] == u]
#
# c:\users\hebbar\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
#    3454                 return self._getitem_multilevel(key)
# -> 3455             indexer = self.columns.get_loc(key)
#    3456             if is_integer(indexer):
#    3457                 indexer = [indexer]
#
# c:\users\hebbar\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: ''

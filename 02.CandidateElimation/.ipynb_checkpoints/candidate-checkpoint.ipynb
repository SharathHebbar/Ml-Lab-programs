# %%
import numpy as np
import pandas as pd
data=pd.DataFrame(data=pd. read_csv('c3.csv'))
concepts=np.array(data.iloc[:,0:-1])
target=np.array(data.iloc[:,-1])

specific_h=['0','0','0','0','0']
general_h=[
    ['?','?','?','?','?'],
    ['?','?','?','?','?'],
    ['?','?','?','?','?'],
    ['?','?','?','?','?'],
    ['?','?','?','?','?']
]
print("The initial hypothesis: ",specific_h)

specific_h=concepts[0].copy()
general=[
        ['?','?','?','?','?'],
        ['?','?','?','?','?'],
        ['?','?','?','?','?'],
        ['?','?','?','?','?'],
        ['?','?','?','?','?']
    ]

hypo = [1,1,1,1,1]
col = len(specific_h)
def specific_general(m,h,s):
    
    if m== 0:
        for k in range(col):
            general[k][k] = s[k] 
    
    if(target[m]  == "malignant"):
        for j in range(col):
            if s[j] == general[j][j] and hypo[j] !=0:
                general[j][j] = s[j]
            elif general[j][j] == '?' and hypo[j] != 0:
                general[j][j] = s[j]
            else:
                general[j][j] = '?'
                hypo[j] = 0

    elif target[m] == 'benign':
        
        for j in range(col):
            if general[j][j] == '?' and hypo[j] != 0:
                general[j][j] = s[j]
            elif h[j] != general[j][j] and hypo[j]!=0: 
                general[j][j] = s[j]
            else:
                general[j][j] = '?'
                hypo[j] = 0
        general_h = general.copy()
    print('general:',general)
            
            

for i,h in enumerate(concepts):
    if target[i]=="malignant" or target[i]=="Y":
        print("\nInstance", i+1 , "is ", h)
        print("Positive instance")
        
        for x in range(len(specific_h)):
            if h[x]!=specific_h[x]:
                specific_h[x]='?'
        
    else:
        print("\nInstance", i+1 , "is ", h)
        print("Negative instance")
    
    hypothesis = h.copy()
    specific_general(i,hypothesis,specific_h)
    
    print("\nSpecific hypothesis after", i+1, "Instance is ", specific_h) 
    print("\nGeneral hypothesis after", i+1, "Instance is ", general_h) 
print("\nThe Maximally Specific hypothesis:",specific_h)
# Out:
# The initial hypothesis:  ['0', '0', '0', '0', '0']
#
# Instance 1 is  ['circular' 'large' 'light' 'smooth' 'thick']
# Positive instance
# general: [['circular', '?', '?', '?', '?'], ['?', 'large', '?', '?', '?'], ['?', '?', 'light', '?', '?'], ['?', '?', '?', 'smooth', '?'], ['?', '?', '?', '?', 'thick']]
#
# Specific hypothesis after 1 Instance is  ['circular' 'large' 'light' 'smooth' 'thick']
#
# General hypothesis after 1 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
# Instance 2 is  ['circular' 'large' 'light' 'irregular' 'thick']
# Positive instance
# general: [['circular', '?', '?', '?', '?'], ['?', 'large', '?', '?', '?'], ['?', '?', 'light', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', 'thick']]
#
# Specific hypothesis after 2 Instance is  ['circular' 'large' 'light' '?' 'thick']
#
# General hypothesis after 2 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
# Instance 3 is  ['oval' 'large' 'dark' 'smooth' 'thin']
# Negative instance
# general: [['circular', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', 'light', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', 'thick']]
#
# Specific hypothesis after 3 Instance is  ['circular' 'large' 'light' '?' 'thick']
#
# General hypothesis after 3 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
# Instance 4 is  ['oval' 'large' 'light' 'irregular' 'thick']
# Positive instance
# general: [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', 'light', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', 'thick']]
#
# Specific hypothesis after 4 Instance is  ['?' 'large' 'light' '?' 'thick']
#
# General hypothesis after 4 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
# Instance 5 is  ['circular' 'small' 'light' 'smooth' 'thick']
# Negative instance
# general: [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
# Specific hypothesis after 5 Instance is  ['?' 'large' 'light' '?' 'thick']
#
# General hypothesis after 5 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
# The Maximally Specific hypothesis: ['?' 'large' 'light' '?' 'thick']
